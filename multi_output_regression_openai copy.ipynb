# %%
import pandas as pd
import numpy as np
from openai import OpenAI
from sklearn.linear_model import Ridge
from sklearn.multioutput import MultiOutputRegressor
from tqdm import tqdm

# === 1. CONFIGURATION ===
API_KEY = "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"  # Replace with your OpenAI API key
openai_model = "text-embedding-3-large"

client = OpenAI(api_key=API_KEY)

# === 2. LOAD AND PREPARE TRAINING DATA ===
df_train = pd.read_excel("test01.xlsx")

# Combine fields into one input string
df_train["text"] = (
    df_train["Systeme"].astype(str) + " | " +
    df_train["Description"].astype(str) + " | " +
    df_train["Description de l'équipement"].astype(str)
)

# Drop rows with missing target scores
df_train = df_train.dropna(subset=["Fiabilité Intégrité", "Disponibilté", "Process Safety"])

X_train_text = df_train["text"].tolist()
y_train = df_train[["Fiabilité Intégrité", "Disponibilté", "Process Safety"]].values


# === 3. EMBEDDING FUNCTION ===
def get_embedding(text: str, model: str = openai_model) -> list:
    try:
        response = client.embeddings.create(input=[text], model=model)
        return response.data[0].embedding
    except Exception as e:
        print(f"Error embedding text: {text[:50]}... -> {e}")
        return [0.0] * 1536  # fallback in case of failure


# === 4. EMBED TRAINING TEXTS ===
print("🔄 Embedding training data...")
X_train_embedded = np.array([get_embedding(text) for text in tqdm(X_train_text)])


# === 5. TRAIN MODEL ===
print("🧠 Training regression model...")
model = MultiOutputRegressor(Ridge())
model.fit(X_train_embedded, y_train)
# Out:
# 🔄 Embedding training data...
# 100%|██████████| 5998/5998 [30:28<00:00,  3.28it/s]
# 🧠 Training regression model...
# MultiOutputRegressor(estimator=Ridge())

# %%
# === 6. LOAD AND EMBED NEW ANOMALIES ===
df_new = pd.read_excel("test01wfi.xlsx")

df_new["text"] = (
    df_new["Systeme"].astype(str) + " | " +
    df_new["Description"].astype(str) + " | " +
    df_new["Description de l'équipement"].astype(str)
)

X_new_text = df_new["text"].tolist()

print("🔄 Embedding new anomaly data...")
# Out:
# 🔄 Embedding new anomaly data...

# %%
X_new_embedded = np.array([get_embedding(text) for text in tqdm(X_new_text)])


# === 7. PREDICT AND FORMAT RESULTS ===
print("🧮 Predicting scores...")
preds = model.predict(X_new_embedded)
preds_df = pd.DataFrame(preds, columns=["Fiabilité Intégrité", "Disponibilté", "Process Safety"])
preds_df = preds_df.round().clip(1, 5).astype(int)
# preds_df = preds_df.clip(lower=1.0, upper=5.0)

# Combine with original input
df_result = pd.concat([df_new, preds_df], axis=1)

# === 8. SAVE TO FILE ===
output_file = "scored_anomalies_openai.xlsx"
df_result.to_excel(output_file, index=False)
print(f"✅ Done! Results saved to {output_file}")
display(df_result.head(20))
# Out:
# 100%|██████████| 20/20 [00:06<00:00,  2.89it/s]
# 🧮 Predicting scores...
# ✅ Done! Results saved to scored_anomalies_openai.xlsx
#                          Num_equipement                               Systeme  \
# 0  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 1  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 2  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 3  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 4  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 5  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 6  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 7  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 8  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 9  3f68d058-b105-46f0-b137-6ce7695b85d1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
#
#                                          Description  \
# 0  Soufflage avec de l'air des radiateur de refro...
# 1  Bruit moto-ventilateur transformateur principa...
# 2          manque éclairage transformateur principal
# 3  Arrêt 7 jours U3 AVR 2021: Entretien préventif...
# 4  Dégagement des portes grillage haut suite risq...
# 5  prévoir changer le silicagel du transformateur...
# 6  netoyage et souflage des radiateurs du transfo...
# 7  Prévoir la remise en état porte transformateur...
# 8  Présence trace d'huile au niveau sortie borne ...
# 9  prévoir le contrôle des indicateur température...
#
#   Description de l'équipement  \
# 0           TRANSFO PRINCIPAL
# 1           TRANSFO PRINCIPAL
# 2           TRANSFO PRINCIPAL
# 3           TRANSFO PRINCIPAL
# 4           TRANSFO PRINCIPAL
# 5           TRANSFO PRINCIPAL
# 6           TRANSFO PRINCIPAL
# 7           TRANSFO PRINCIPAL
# 8           TRANSFO PRINCIPAL
# 9           TRANSFO PRINCIPAL
#
#                                                 text  Fiabilité Intégrité  \
# 0  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Souffla...                    2
# 1  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Bruit m...                    3
# 2  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | manque ...                    2
# 3  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Arrêt 7...                    2
# 4  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Dégagem...                    2
# 5  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | prévoir...                    2
# 6  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | netoyag...                    2
# 7  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Prévoir...                    2
# 8  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Présenc...                    2
# 9  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | prévoir...                    2
#
#    Disponibilté  Process Safety
# 0             4               1
# 1             4               1
# 2             3               3
# 3             3               2
# 4             3               4
# 5             3               2
# 6             4               1
# 7             3               2
# 8             4               2
# 9             3               1

# %%
display(df_result.head(20))
# Out:
#                           Num_equipement  \
# 0   3f68d058-b105-46f0-b137-6ce7695b85d1
# 1   3f68d058-b105-46f0-b137-6ce7695b85d1
# 2   3f68d058-b105-46f0-b137-6ce7695b85d1
# 3   3f68d058-b105-46f0-b137-6ce7695b85d1
# 4   3f68d058-b105-46f0-b137-6ce7695b85d1
# 5   3f68d058-b105-46f0-b137-6ce7695b85d1
# 6   3f68d058-b105-46f0-b137-6ce7695b85d1
# 7   3f68d058-b105-46f0-b137-6ce7695b85d1
# 8   3f68d058-b105-46f0-b137-6ce7695b85d1
# 9   3f68d058-b105-46f0-b137-6ce7695b85d1
# 10  3f68d058-b105-46f0-b137-6ce7695b85d1
# 11  3f68d058-b105-46f0-b137-6ce7695b85d1
# 12  3f68d058-b105-46f0-b137-6ce7695b85d1
# 13  3f68d058-b105-46f0-b137-6ce7695b85d1
# 14  3f68d058-b105-46f0-b137-6ce7695b85d1
# 15  3f68d058-b105-46f0-b137-6ce7695b85d1
# 16  3f68d058-b105-46f0-b137-6ce7695b85d1
# 17  3f68d058-b105-46f0-b137-6ce7695b85d1
# 18  3f68d058-b105-46f0-b137-6ce7695b85d1
# 19  3f68d058-b105-46f0-b137-6ce7695b85d1
#
#                                  Systeme  \
# 0   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 1   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 2   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 3   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 4   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 5   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 6   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 7   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 8   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 9   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 10  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 11  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 12  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 13  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 14  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 15  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 16  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 17  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 18  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
# 19  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd
#
#                                           Description  \
# 0   Soufflage avec de l'air des radiateur de refro...
# 1   Bruit moto-ventilateur transformateur principa...
# 2           manque éclairage transformateur principal
# 3   Arrêt 7 jours U3 AVR 2021: Entretien préventif...
# 4   Dégagement des portes grillage haut suite risq...
# 5   prévoir changer le silicagel du transformateur...
# 6   netoyage et souflage des radiateurs du transfo...
# 7   Prévoir la remise en état porte transformateur...
# 8   Présence trace d'huile au niveau sortie borne ...
# 9   prévoir le contrôle des indicateur température...
# 10                        prévoir soufflage radiateur
# 11  apparition alarme 30bat10cf001 ( transfo princ...
# 12  Arrêt U3: Remise en état du réseau de terre du...
# 13  Arrêt U3: Remise en état du réseau de terre du...
# 14     PREVOIR LE SOUFFLAGE DES RADIATEUR TEMP ELEVEE
# 15     PREVOIR LE SOUFFLAGE DES RADIATEUR TEMP ELEVEE
# 16  SAFETY : Fuite par bride  radiateur du transfo...
# 17  SAFETY : Fuite par bride  radiateur du transfo...
# 18  Prévoir soufflage des radiateur du transformat...
# 19  Prévoir soufflage des radiateur du transformat...
#
#    Description de l'équipement  \
# 0            TRANSFO PRINCIPAL
# 1            TRANSFO PRINCIPAL
# 2            TRANSFO PRINCIPAL
# 3            TRANSFO PRINCIPAL
# 4            TRANSFO PRINCIPAL
# 5            TRANSFO PRINCIPAL
# 6            TRANSFO PRINCIPAL
# 7            TRANSFO PRINCIPAL
# 8            TRANSFO PRINCIPAL
# 9            TRANSFO PRINCIPAL
# 10           TRANSFO PRINCIPAL
# 11           TRANSFO PRINCIPAL
# 12           TRANSFO PRINCIPAL
# 13           TRANSFO PRINCIPAL
# 14           TRANSFO PRINCIPAL
# 15           TRANSFO PRINCIPAL
# 16           TRANSFO PRINCIPAL
# 17           TRANSFO PRINCIPAL
# 18           TRANSFO PRINCIPAL
# 19           TRANSFO PRINCIPAL
#
#                                                  text  Fiabilité Intégrité  \
# 0   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Souffla...                    2
# 1   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Bruit m...                    3
# 2   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | manque ...                    2
# 3   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Arrêt 7...                    2
# 4   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Dégagem...                    2
# 5   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | prévoir...                    2
# 6   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | netoyag...                    2
# 7   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Prévoir...                    2
# 8   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Présenc...                    2
# 9   e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | prévoir...                    2
# 10  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | prévoir...                    2
# 11  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | apparit...                    3
# 12  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Arrêt U...                    2
# 13  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Arrêt U...                    2
# 14  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | PREVOIR...                    2
# 15  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | PREVOIR...                    2
# 16  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | SAFETY ...                    2
# 17  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | SAFETY ...                    2
# 18  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Prévoir...                    2
# 19  e4f67f5f-be46-4ce0-ad14-68575d3cf0cd | Prévoir...                    2
#
#     Disponibilté  Process Safety
# 0              4               1
# 1              4               1
# 2              3               3
# 3              3               2
# 4              3               4
# 5              3               2
# 6              4               1
# 7              3               2
# 8              4               2
# 9              3               1
# 10             4               2
# 11             4               2
# 12             4               2
# 13             4               2
# 14             4               1
# 15             4               1
# 16             4               5
# 17             4               5
# 18             4               1
# 19             4               1
